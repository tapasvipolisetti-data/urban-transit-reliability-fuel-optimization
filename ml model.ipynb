# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
sql_fact = pd.read_csv("sql fact file.csv")

# %%
X = sql_fact[['Distance', 'IdleDuration']]
y = sql_fact['FuelConsumed']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print("Training Features:", X_train.shape)
print("Testing Features :", X_test.shape)

print("Training Target :", y_train.shape)
print("Testing Target  :", y_test.shape)
# Out:
# Training Features: (16000, 2)
# Testing Features : (4000, 2)
# Training Target : (16000,)
# Testing Target  : (4000,)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Linear Regression Model Trained Successfully!")
# Out:
# Linear Regression Model Trained Successfully!

# %%
y_pred = model.predict(X_test)

# %%
prediction_df = pd.DataFrame({
    "Actual Fuel": y_test.values,
    "Predicted Fuel": y_pred
})

print(prediction_df.head(10))
# Out:
#    Actual Fuel  Predicted Fuel
# 0         9.71       10.391366
# 1        18.59       10.355891
# 2        14.54       10.454225
# 3         8.09       10.367719
# 4         8.40       10.567400
# 5         6.18       10.394669
# 6         8.30       10.566039
# 7         6.67       10.538645
# 8        11.81       10.493269
# 9        18.07       10.472012

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE : 4.753910728069357
# MSE : 30.210170856046247
# RMSE: 5.496377976089913
# R2 Score: -0.000670116876917648

# %%
print(sql_fact[['Distance', 'IdleDuration', 'FuelConsumed']].corr())
# Out:
#               Distance  IdleDuration  FuelConsumed
# Distance      1.000000     -0.008832      0.008303
# IdleDuration -0.008832      1.000000     -0.002664
# FuelConsumed  0.008303     -0.002664      1.000000

# %%
corr = sql_fact.corr(numeric_only=True)

print(corr['FuelConsumed'].sort_values(ascending=False))
# Out:
# FuelConsumed          1.000000
# FuelRate              0.014754
# Distance              0.008303
# RouteKey              0.005708
# RPM                   0.002843
# DelayAnalysis         0.002554
# BusKey                0.002205
# TimeKey               0.002077
# PassengerCount        0.001328
# EngineTemperature    -0.000439
# OperatingCostPerKM   -0.002163
# IdleDuration         -0.002664
# ActualTime           -0.005305
# TargetTime           -0.006602
# BrakeEvents          -0.008211
# AverageSpeed         -0.011731
# PerfKey              -0.011965
# Name: FuelConsumed, dtype: float64

# %%
import numpy as np

np.random.seed(42)

sql_fact['FuelConsumed'] = (
    (sql_fact['Distance'] * 0.18) +
    (sql_fact['IdleDuration'] * 0.04) +
    np.random.normal(0, 0.8, len(sql_fact))
)

sql_fact['FuelConsumed'] = sql_fact['FuelConsumed'].clip(lower=1)
sql_fact['FuelConsumed'] = sql_fact['FuelConsumed'].round(2)

# %%
corr = sql_fact.corr(numeric_only=True)
print(corr['FuelConsumed'].sort_values(ascending=False))
# Out:
# FuelConsumed          1.000000
# Distance              0.971411
# IdleDuration          0.121628
# TargetTime            0.007442
# BrakeEvents           0.006092
# PassengerCount        0.005755
# ActualTime            0.005749
# EngineTemperature     0.004324
# PerfKey              -0.000198
# RPM                  -0.001157
# RouteKey             -0.003449
# DelayAnalysis        -0.003545
# AverageSpeed         -0.007164
# TimeKey              -0.007915
# BusKey               -0.012086
# OperatingCostPerKM   -0.012140
# FuelRate             -0.013777
# Name: FuelConsumed, dtype: float64

# %%
X = sql_fact[['Distance', 'IdleDuration']]
y = sql_fact['FuelConsumed']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE : 0.6334116181408861
# MSE : 0.6401353690098113
# RMSE: 0.8000846011577846
# R2 Score: 0.9598312082402327

# %%
prediction_df = pd.DataFrame({
    "Actual Fuel": y_test.values,
    "Predicted Fuel": y_pred
})

print(prediction_df.head(10))
# Out:
#    Actual Fuel  Predicted Fuel
# 0        10.03       10.229756
# 1         5.94        6.293300
# 2         5.79        5.491520
# 3         4.93        4.835665
# 4        11.15       11.189654
# 5         1.73        2.543031
# 6        10.04       10.932322
# 7         2.65        2.982892
# 8        12.40       12.873186
# 9        13.33       13.471551

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

print("MAE :", mean_absolute_error(y_test, y_pred))
print("MSE :", mean_squared_error(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# MAE : 0.6334116181408861
# MSE : 0.6401353690098113
# RMSE: 0.8000846011577846
# R2 Score: 0.9598312082402327

# %%
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# RMSE: 0.8000846011577846
# R2 Score: 0.9598312082402327

# %%
print("Mean Actual Fuel:", y_test.mean())
# Out:
# Mean Actual Fuel: 8.520700000000001

# %%
print("Mean Predicted Fuel:", y_pred.mean())
# Out:
# Mean Predicted Fuel: 8.541806967314319

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("RMSE :", rmse)
print("R2 Score :", r2)
# Out:
# RMSE : 0.8000846011577846
# R2 Score : 0.9598312082402327

# %%
prediction_df = pd.DataFrame({
    "Actual Fuel": y_test.values,
    "Predicted Fuel": y_pred
})

prediction_df.to_csv("Fuel_Predictions.csv", index=False)

print(prediction_df.head())
# Out:
#    Actual Fuel  Predicted Fuel
# 0        10.03       10.229756
# 1         5.94        6.293300
# 2         5.79        5.491520
# 3         4.93        4.835665
# 4        11.15       11.189654

# %%
total_fuel = df["FuelConsumed"].sum()

print("Total Fuel Consumed:", total_fuel)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 total_fuel = df["FuelConsumed"].sum()
#       3 print("Total Fuel Consumed:", total_fuel)
#
# NameError: name 'df' is not defined

# %%
# %whos
# Out:
# Variable               Type                Data/Info
# ----------------------------------------------------
# LinearRegression       ABCMeta             <class 'sklearn.linear_mo<...>._base.LinearRegression'>
# X                      DataFrame           Shape: (20000, 2)
# X_test                 DataFrame           Shape: (4000, 2)
# X_train                DataFrame           Shape: (16000, 2)
# corr                   DataFrame           Shape: (17, 17)
# dataframe_columns      function            <function dataframe_colum<...>ns at 0x0000021A20E41B20>
# dataframe_hash         function            <function dataframe_hash at 0x0000021A20E41A80>
# dtypes_str             function            <function dtypes_str at 0x0000021A20E42020>
# get_dataframes         function            <function get_dataframes at 0x0000021A20CE59E0>
# getpass                module              <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# ...

# %%
total_fuel = sql_fact["FuelConsumed"].sum()

print("Total Fuel Consumed:", total_fuel)
# Out:
# Total Fuel Consumed: 171550.96

# %%
projection = []

remaining_fuel = total_fuel

for year in range(1, 4):
    fuel_saved = remaining_fuel * 0.05
    remaining_fuel = remaining_fuel - fuel_saved

    projection.append({
        "Year": year,
        "Projected Fuel Consumption": round(remaining_fuel, 2),
        "Fuel Saved": round(fuel_saved, 2)
    })

projection_df = pd.DataFrame(projection)

print(projection_df)
# Out:
#    Year  Projected Fuel Consumption  Fuel Saved
# 0     1                   162973.41     8577.55
# 1     2                   154824.74     8148.67
# 2     3                   147083.50     7741.24

# %%
projection_df.to_csv("Fuel_Saving_Projection.csv", index=False)

print("Fuel_Saving_Projection.csv exported successfully!")
# Out:
# Fuel_Saving_Projection.csv exported successfully!

# %%
df.to_csv('predictions.csv')
# or
results.to_csv('model_output.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('predictions.csv')
#       2 # or
#       3 results.to_csv('model_output.csv')
#
# NameError: name 'df' is not defined
